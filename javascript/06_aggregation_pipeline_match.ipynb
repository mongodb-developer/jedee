// %% [markdown]
// [![Aggregation Pipeline Lab](https://img.shields.io/badge/Lab%20Documentation%20and%20Solutions-darkgreen)](https://mongodb-developer.github.io/aggregation-pipeline-lab/)

// %% [markdown]
// # Aggregation Pipeline

// %% [markdown]
// ## Import the MongoDB Driver

// %%
import { MongoClient } from "npm:mongodb@5.6.0";

// %% [markdown]
// ## Set your connection String below

// %%
const mongoDBURI = 'mongodb://admin:mongodb@localhost:27017/?directConnection=true';

// %% [markdown]
// ## $match

// %%
const client = new MongoClient(mongoDBURI);

try {
  await client.connect();
  console.log("Connected to MongoDB!");
} catch (error) {
  console.error("Error connecting to MongoDB:", error);
}


// Database Name
const dbName = 'library';

const db = client.db(dbName);
const books = db.collection("books");
// Out:
// Connected to MongoDB!

// %% [markdown]
// ### $match

// %%
const pipeline = [
   { $match: { year: 2010 } }
];

const cursor = await books.aggregate( pipeline );

await cursor.forEach((b) => {
   console.log(b);
});
// Out:
// {
//   _id: "61066583",
//   title: "Treasure of the Sun",
//   pages: 448,
//   year: 2010,
//   synopsis: "<P>Theirs was a Passion as Fierce as the Land that Claimed Them <P>Black-eyed Damian de la Sola was like no man Katherine Maxwell had ever known. Powerful and seductive, the aristocratic Spaniard unleashed a passion the Boston beauty vowed to resist. <P>De la Sola's blood ran hot for the bewitching widow of his most trusted American ally.Consumed by love and honor-bound to protect her, he relentlessly pursued her into the California wilderness. <P>Together, they followed their destinies. From a magnificent hacienda to a glittering cave carved deep in the mountainside, they searched for a golden treasure&#151;and discovered a priceless love.<P>A Magnificent Novel of Love and Adventure in the Untamed American West<h3>Romantic Times</h3>Christina Dodd&#39;s talents continue to grow and readers are guaranteed pleasure and true enjoyment.",
//   cover: "https://images.isbndb.com/covers/06/27/9780061040627.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "Treasure of the Sun",
//   bookOfTheMonth: null,
//   tags: "war,drama",
//   publisherId: 1946,
//   bindingId: 12,
//   languageId: 1,
//   authors: [ { authorId: 771, name: "Christina Dodd" } ],
//   binding: { id: 12, name: "Mass Market Paperback" },
//   attributes: [
//     { key: "edition", value: "Reissue" },
//     {
//       key: "dimensions",
//       value: "Height: 6.75 Inches, Length: 4.19 Inches, Width: 1.12 Inches"
//     },
//     { key: "isbn13", value: "9780061040627" },
//     { key: "msrp", value: "0.00" },
//     { key: "isbn", value: "61040622" },
//     { key: "isbn10", value: "61040622" }
//   ],
//   genre: [
//     { genreId: 559, name: "Fiction" },
//     { genreId: 2837, name: "Romance" }
//   ],
//   publisher: { id: 1946, name: "Avon" }
// }
// {
//   _id: "1571671749",
//   title: "Piecing",
//   pages: 162,
//   year: 2010,
//   synopsis: "Ruth's sought-after techniques for original pieced design. Includes curved seams, insets, multiple angles, Z seams, puzzle seams, and much more!",
//   cover: "https://images.isbndb.com/covers/04/19/9781571200419.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "Piecing",
//   bookOfTheMonth: null,
//   tags: "indie author",
//   publisherId: 616,
//   bindingId: 6,
//   languageId: 1,
//   authors: [ { authorId: 6068, name: "Ruth B. McDowell" } ],
//   binding: { id: 6, name: "Paperback" },
//   attributes: [
//     {
//       key: "dimensions",
//       value: "Height: 10.99 Inches, Length: 8.5 Inches, Weight: 0.86421206704 Pounds, Width: 0.52 Inches"
//     },
//     { key: "isbn13", value: "9781571200419" },
//     { key: "msrp", value: "27.95" },
//     { key: "isbn", value: "157120041X" },
//     { key: "isbn10", value: "157120041X" }
//   ],
//   genre: [
//     { genreId: 3823, name: "Patchwork" },
//     { genreId: 2030, name: "Crafts &amp; Hobbies" }
//   ],
//   publisher: { id: 616, name: "C&T Publishing" }
// }
// {
//   _id: "374102112",
//   title: "Sweet Thing (Cheek)",
//   pages: 256,
//   year: 2010,
//   synopsis: "jessica Taylor Is An La Girl Through And Through&#58; Ambitious, Stylish, And A Big Fan Of Old Hollywood Movies. What She Wants More Than Anything Is To Become An Ace Reporter. Her Editor, Dashiell Cooper, Holds That Key, But What He Wants Most Of All Is Her. Jessica Is Starry-eyed But Not As Easily Pinned Down As The Cynical Cooper Would Like. He Uses A Whole Repertoire Of Charmer's Tricks To Try And Seduce Her, But She Challenges Him At Every Turn, Finding Her Pleasure Playing X-rated Games With Sultry-looking Guys Who Resemble James Dean. What Transpires Is A Game Of Kinky Cat And Mouse Set In The Hush-hush World Of La Gossip Columns And Glamorous Parties. Can Jessica Get What She Wants Without Giving In To Cooper's Erotic Obsessions?",
//   cover: "Https://images.isbndb.com/covers/90/03/9780352339003.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "Sweet Thing (Cheek)",
//   bookOfTheMonth: null,
//   tags: "weekend read,fair",
//   publisherId: 46,
//   bindingId: 15,
//   languageId: 1,
//   authors: [ { authorId: 3487, name: "Alison Tyler" } ],
//   binding: { id: 15, name: "Kindle Edition" },
//   attributes: [
//     { key: "edition", value: "New" },
//     { key: "isbn13", value: "9780352339003" },
//     { key: "msrp", value: "0.00" },
//     { key: "isbn", value: "352339004" },
//     { key: "isbn10", value: "352339004" }
//   ],
//   genre: [
//     { genreId: 559, name: "Fiction" },
//     { genreId: 6402, name: "erotica" },
//     { genreId: 1852, name: "general" },
//     { genreId: 2875, name: "Los angeles (calif.)" },
//     { genreId: 1901, name: "fiction" }
//   ],
//   publisher: { id: 46, name: "Virgin Digital" }
// }
// {
//   _id: "1555833837",
//   title: "Michigan (America)",
//   pages: 96,
//   year: 2010,
//   synopsis: "<br>\\n<br>\\nWhether the attraction is historic lighthouses, thriving communities or beautiful parks, Michigan has something to offer any visitor and many surprises for residents.<br>\\n<br>\\n<b>About the</b> <i>America</i> <b>series:</b><br>\\n<br>\\nAs expansive as America itself, this outstanding series captures outstanding views of panoramic landscapes, brilliant city skylines, and picturesque communities. Each volume focuses on a city or state and features 96 pages and 70 stunning images by internationally renowned photographers, plus descriptive captions.<br>\\n<br>",
//   cover: "https://images.isbndb.com/covers/11/42/9781552851142.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "Michigan (America)",
//   bookOfTheMonth: null,
//   tags: "justice,fall read",
//   publisherId: 52,
//   bindingId: 19,
//   languageId: 1,
//   authors: [ { authorId: 2671, name: "Tanya Lloyd Kyi" } ],
//   binding: { id: 19, name: "Hardcover" },
//   attributes: [
//     { key: "edition", value: "1" },
//     {
//       key: "dimensions",
//       value: "Height: 10.25 Inches, Length: 10.5 Inches, Weight: 1.65 Pounds, Width: 0.5 Inches"
//     },
//     { key: "isbn13", value: "9781552851142" },
//     { key: "msrp", value: "19.95" },
//     { key: "isbn", value: "1552851141" },
//     { key: "isbn10", value: "1552851141" }
//   ],
//   publisher: { id: 52, name: "Whitecap America" },
//   reviews: [
//     {
//       text: "The book was average. The story was decent, but the characters lacked depth and development. The pacing was inconsistent, making it hard to stay engaged. Overall, it was an okay read.",
//       rating: new Decimal128("3"),
//       timestamp: 2019-02-08T10:24:24.249Z,
//       userId: 40
//     },
//     {
//       text: "This book was a rollercoaster of emotions! The characters were well-developed and relatable, and the plot kept me engaged from start to finish. The writing style was beautiful and descriptive, painting vivid images in my mind. However, there were a few moments where the pacing felt a bit slow. Overall, I highly recommend this book for anyone who loves a gripping and emotional read.",
//       rating: new Decimal128("4"),
//       timestamp: 2022-11-03T08:56:50.996Z,
//       userId: 41
//     },
//     {
//       text: "This book is absolutely amazing! The characters are well-developed, the plot is captivating, and the writing style is superb. I couldn't put it down once I started reading. Highly recommended!",
//       rating: new Decimal128("5"),
//       timestamp: 2023-02-06T03:51:56.765Z,
//       userId: 42
//     }
//   ]
// }
// {
//   _id: "553377957",
//   title: "Ride the River: The Sacketts: A Novel",
//   pages: 186,
//   year: 2010,
//   synopsis: "filled With Exciting Tales Of The Frontier, The Chronicle Of The Sackett Family Is Perhaps The Crowning Achievement Of One Of Our Greatest Storytellers. In Ride The River Louis L'amour Spins The Tale Of A Young Woman Who Has To Protect Her Family Fortune From A Murderous Thief-and Teaches Him What It Means To Be A Sackett... Sixteen-year-old Echo Sackett Had Never Been Far From Her Tennessee Home-until She Made The Long Trek To Philadelphia To Collect An Inheritance. Echo Could Take Care Of Herself As Well As Any Sackett Man, But James White, A Sharp City Lawyer, Figured That Cheating The Money From The Young Country Girl Would Be Like Taking Candy From A Baby. If He Couldn't Hoodwink Echo Out Of The Cash, He'd Just Steal It From Her Outright. And If She Put Up A Fight? There Were Plenty Of Accidents That Could Happen To A Country Girl On Her First Trip To The Big City...",
//   cover: "https://images.isbndb.com/covers/68/31/9780553276831.jpg",
//   totalInventory: 1,
//   available: 1,
//   longTitle: "Ride the River: The Sacketts: A Novel",
//   bookOfTheMonth: null,
//   tags: "true crime,bookstagram",
//   publisherId: 1472,
//   bindingId: 12,
//   languageId: 1,
//   authors: [ { authorId: 46, name: "Louis L'Amour" } ],
//   binding: { id: 12, name: "Mass Market Paperback" },
//   attributes: [
//     { key: "edition", value: "Reissue" },
//     {
//       key: "dimensions",
//       value: "Height: 6.9 Inches, Length: 4.15 Inches, Weight: 0.22487150724 Pounds, Width: 0.55 Inches"
//     },
//     { key: "isbn13", value: "9780553276831" },
//     { key: "msrp", value: "5.99" },
//     { key: "isbn", value: "553276832" },
//     { key: "isbn10", value: "553276832" }
//   ],
//   publisher: { id: 1472, name: "Bantam" }
// }
// {
//   _id: "380795191",
//   title: "Shadow of a Dark Queen (The Serpentwar Saga, Book 1)",
//   pages: 497,
//   year: 2010,
//   synopsis: "The Serpentwar Saga, a classic of fantasy fiction, is available at last in e-book format: Shadow of a Dark Queen; Rise of a Merchant Prince; Rage of a Demon King; Shards of a Broken Crown. <h3>Publishers Weekly</h3> A dark and alien peril casts an lengthening shadow over Midkemia as another Riftworld saga begins almost a generation after the events in The King's Buccaneer . Erik von Darkmoor, bastard son of the local baron, flees to the city of Krondor after accidentally killing his legitimate and sadistic half-brother. Condemned to death, Eric and his childhood friend, Rupert (Roo) Avery, are provisionally spared to serve in a desperate mission against the reptilian Pantathians, who plan to conquer Midkemia and bring back their goddess, Alma-Lodaka, one of the ancient Dragon Lords. The boys undergo brutal training and join others of their kind under the half-elf Calis, known as the Eagle of Krondor, in a bid to pass as mercenaries in the continent of Novindus, current battle center for the Pantathians and their reluctant allies, the also-reptilian Saaur. A sensitive coming-of-age tale in which brutality and camaraderie are equally present, Feist's newest saga has a freshness of vision that suggests it will avoid the staleness that often eats away at multivolume epics. Author tour. (July)",
//   cover: "https://images.isbndb.com/covers/08/66/9780380720866.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "Shadow of a Dark Queen (The Serpentwar Saga, Book 1)",
//   bookOfTheMonth: null,
//   tags: "new release,sports",
//   publisherId: 1742,
//   bindingId: 12,
//   languageId: 1,
//   authors: [ { authorId: 679, name: "Raymond E. Feist" } ],
//   binding: { id: 12, name: "Mass Market Paperback" },
//   attributes: [
//     { key: "edition", value: "Reissue" },
//     {
//       key: "dimensions",
//       value: "Height: 6.75 Inches, Length: 4.1875 Inches, Weight: 0.55 Pounds, Width: 1.056 Inches"
//     },
//     { key: "isbn13", value: "9780380720866" },
//     { key: "msrp", value: "4.99" },
//     { key: "isbn", value: "380720868" },
//     { key: "isbn10", value: "380720868" }
//   ],
//   publisher: { id: 1742, name: "EOS" }
// }
// {
//   _id: "590396439",
//   title: "Don't Drink the Water",
//   pages: 88,
//   year: 2010,
//   synopsis: `Farce / 12m, 4f / Int. \\nA cascade of comedy and a solid hit on Broadway, this affair takes place inside an American embassy behind the Iron Curtain. An American tourist, a caterer by trade, and his wife and daughter rush into the embassy two steps ahead of the police who suspect them of spying and picture taking. It's not much of a refuge, for the ambassador is absent and his son, now in charge, has been expelled from a dozen countries and the continent of Africa. Nevertheless, they carefully and frantically plot their escape, and the ambassador's son and the caterer's daughter even have time to fall in love.\\n"Moved the audience to great laughter.... Allen's imagination is daffy, his sense of the ridiculous is keen and gags snap, crackle and pop." N.Y. Daily News\\n"It is filled with ... bright and hilarious dialogue." N.Y. Post.`,
//   cover: "https://images.isbndb.com/covers/81/79/9780573608179.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "Don't Drink the Water",
//   bookOfTheMonth: null,
//   tags: "fantasy,cultural issues",
//   publisherId: 1024,
//   bindingId: 6,
//   languageId: 1,
//   authors: [ { authorId: 909, name: "Woody Allen" } ],
//   binding: { id: 6, name: "Paperback" },
//   attributes: [
//     {
//       key: "dimensions",
//       value: "Height: 8 Inches, Length: 5 Inches, Weight: 0.21 Pounds, Width: 0.18 Inches"
//     },
//     { key: "isbn13", value: "9780573608179" },
//     { key: "msrp", value: "10.95" },
//     { key: "isbn", value: "573608172" },
//     { key: "isbn10", value: "573608172" }
//   ],
//   publisher: { id: 1024, name: "Samuel French, Inc." }
// }
// {
//   _id: "945397348",
//   title: "I Died Laughing: Funeral Education with a Light Touch",
//   pages: 96,
//   year: 2010,
//   synopsis: 'This is a very funny book, even though it also includes some serious consumer information. Lisa Carlson has collected cartoons, jokes, funny quotations, humorous last words, and a wide range of other old and new material. As the advice columnist Dear Abby remarked, "This book proves that dying can be a laughing matter." At the end of each section, Carlson has a page or two of information and advice for those who may someday have the job of arranging a funeral for a friend or relative, or who may be contemplating the arrangements they prefer when they die.Half the profits from sale of the book will be contributed to the work of the national nonprofit consumer organization, Funeral Consumers Alliance. Several well-known cartoonists and illustrators made their work available in support of this cause: these include P.S. Mueller, Rina Picccolo, and the estate of Edward Gorey.With this short book, you can have a good laugh, learn something in process, and support good cause at the same time.',
//   cover: "https://images.isbndb.com/covers/92/50/9780942679250.jpg",
//   totalInventory: 2,
//   available: 2,
//   longTitle: "I Died Laughing: Funeral Education with a Light Touch",
//   bookOfTheMonth: null,
//   tags: "long read,gothic fiction,travel",
//   publisherId: 92,
//   bindingId: 6,
//   languageId: 1,
//   authors: [ { authorId: 3872, name: "Lisa Carlson" } ],
//   binding: { id: 6, name: "Paperback" },
//   attributes: [
//     { key: "edition", value: "New Edition" },
//     {
//       key: "dimensions",
//       value: "Height: 8.3 Inches, Length: 5.5 Inches, Weight: 0.32628414776 Pounds, Width: 0.2 Inches"
//     },
//     { key: "isbn13", value: "9780942679250" },
//     { key: "msrp", value: "7.64" },
//     { key: "isbn", value: "942679253" },
//     { key: "isbn10", value: "942679253" }
//   ],
//   publisher: { id: 92, name: "Upper Access, Inc." }
// }
// {
//   _id: "1552093115",
//   title: "New Mexico (America)",
//   pages: 96,
//   year: 2010,
//   synopsis: "<br>\\n<br>\\nBadlands and ruins, hot air balloons and pueblo life -- somewhere between the pop fame of Route 66 and prehistoric landscape of Carlsbad Caverns is the spirit of New Mexico: ancient and breath taking. Santa Fe and Albuquerque are alive with Spanish dance, modern architecture and painting, while vibrant native cultures thrive throughout the state. Visitors enjoy activities such as world-class skiing at Taos and white-water rafting along the legendary Rio Grande. In <b>New Mexico</b>, some of North America's best photographers celebrate this intriguing state, from ghost towns and sacred sites to vital urban communities and snowy wilderness scenes.<br>\\n<br>\\n<b>About the</b> <i>America</i> <b>series:</b><br>\\n<br>\\nAs expansive as America itself, this outstanding series captures outstanding views of panoramic landscapes, brilliant city skylines, and picturesque communities. Each volume focuses on a city or state and features 96 pages and 70 stunning images by internationally renowned photographers, plus descriptive captions.<br>\\n<br>",
//   cover: "https://images.isbndb.com/covers/86/36/9781551108636.jpg",
//   totalInventory: 1,
//   available: 1,
//   longTitle: "New Mexico (America)",
//   bookOfTheMonth: null,
//   tags: "photography,law",
//   publisherId: 52,
//   bindingId: 19,
//   languageId: 1,
//   authors: [ { authorId: 2671, name: "Tanya Lloyd Kyi" } ],
//   binding: { id: 19, name: "Hardcover" },
//   attributes: [
//     { key: "edition", value: "1" },
//     {
//       key: "dimensions",
//       value: "Height: 10.26 Inches, Length: 10.3 Inches, Weight: 1.72 Pounds, Width: 0.6 Inches"
//     },
//     { key: "isbn13", value: "9781551108636" },
//     { key: "msrp", value: "19.95" },
//     { key: "isbn", value: "1551108631" },
//     { key: "isbn10", value: "1551108631" }
//   ],
//   publisher: { id: 52, name: "Whitecap America" }
// }

// %% [markdown]
// ### $limit

// %%
import org.bson.types.ObjectId;

Document bookFrom1500 = new Document("_id", "platero"); 

FindIterable<Document> cursor = books.find(bookFrom1500);

if (cursor != null) {
    for(Document b: cursor) {
        System.out.println("Book: " + b.toJson());
    }
} else {
    System.out.println("Empty collection");
}

// %% [markdown]
// ### Delete that book

// %%
import com.mongodb.client.result.DeleteResult;


Document bookFrom1500 = new Document("year", 1500);

DeleteResult deleteResult = books.deleteOne(new Document("_id", "platero"));

// Check the number of deleted documents
long deletedCount = deleteResult.getDeletedCount();
System.out.println("Deleted " + deletedCount + " document(s).");
