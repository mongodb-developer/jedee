# %% [markdown]
# [![Aggregation Pipeline Lab](https://img.shields.io/badge/Lab%20Documentation%20and%20Solutions-darkgreen)](https://mongodb-developer.github.io/aggregation-pipeline-lab/)

# %% [markdown]
# # Aggregation Pipeline $group

# %% [markdown]
# ## Startup code

# %%
# Import the MongoDB Driver
from pymongo import MongoClient

# Set your connection String
mongoDBURI = "mongodb://admin:mongodb@localhost:27017/?directConnection=true";

# Create a MongoDB Client
client = MongoClient(mongoDBURI)

# Get the Library Database
db = client["library"]

# Get the Books Collection
books = db["books"]

# %%
pipeline = [
    {"$group":{
        "_id": "$year",
        "totalBooks": {"$sum": 1}
    } },
    { "$sort": {
        "_id":1
    } },
    { "$limit": 10 }
]

# Execute the aggregate operation
result = books.aggregate(pipeline)

for f in result:
    print(f" books per year: {f}.")

# %% [markdown]
# Get the results ordered ascending by year

# %%
pipeline = [
    {
        "$group": {
            "_id": "$year",
            "totalBooks": { "$sum": 1 },
            "totalPagesPublished": { "$sum": "$pages" },
            "avgPagesPublished": { "$avg": "$pages" },
        }
    },
    {
        "$sort": { "_id": 1 }
    },
    { "$limit": 10 }
]

result = list(books.aggregate(pipeline))

for book in result:
    print(book)
