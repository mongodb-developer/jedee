# %% [markdown]
# # CRUD: find

# %%
from pymongo import MongoClient


uri = "mongodb://admin:mongodb@localhost:27017/"
client = MongoClient(uri)
library_database = client["library"]

books = library_database["books"]

# %% [markdown]
# ## Find one book

# %%
books.find_one()

# %% [markdown]
# ## Find books written after 2008

# %%
results = books.find({ "year": { "$gt" : 2008 }})

for f in results:
    print(f)

# %% [markdown]
# ## Exercise: find all the books that have less than 50 pages and print only the title and pages

# %%
filter = { "pages": { "$lt" : 50 }}
results = books.find(filter)

for f in results:
    print(f"{f['title']} - {f['pages']} - {f['year']}.")

# %% [markdown]
# ## Exercise: find all the books that have less than 50 pages and were published after 2008. Print only title, pages and year

# %%
filter = { 
    "$and": [
        { "pages": { "$lt": 50 }},
        { "year": { "$gt" : 2008 }}
    ]
}

results = books.find(filter)

for f in results:
    print(f"{f['title']} - {f['pages']} - {f['year']}.")

# %%
filter = { 
    "$or": [
        { "pages": { "$lt": 50 }},
        { "year": { "$gt" : 2008 }}
    ]
}

results = books.find(filter)

for f in results:
    print(f"{f['title']} - {f['pages']} - {f['year']}.")
# Out:
# I Like Bugs (Step-Into-Reading, Step 1) - 32 - 1999.
# How You Were Born - 48 - 1993.
# Vanishing Valentines (Scooby-Doo! Picture Clue Book, No. 10) - 32 - 2002.
# Nightwork: Sexuality, Pleasure, and Corporate Masculinity in a Tokyo Hostess Club - 228 - 2009.
# The Man Who Could Call Down Owls - 32 - 1984.
# Corduroy - 28 - 1976.
# Quidditch Through the Ages - 64 - 2015.
# The pretender - 275 - 2022.
# Going to Bed (What I Like No. 4) - 20 - 1988.
# The Teeny Tiny Woman (Step into Reading) - 32 - 1986.
# Chester the Chick (How Your Pet Grows) - 24 - 1988.
# The Living: A Novel - 416 - 2013.
# The Pop-Up Book of Captain Planet and the Planeteers - 1 - 1992.
# Sharpe's Tiger (Richard Sharpe's Adventure Series #1) - 400 - 2012.
# Cartooning with the Simpsons - 32 - 1993.
# Elmo's Mother Goose (Sesame Street) (Big Bird's Favorites Board Books) - 12 - 2000.
# Done Deal (John Deal Series) - 299 - 2012.
# Oscar's New Neighbor - 1 - 1994.
# George and Martha Rise and Shine - 48 - 1979.
# My First Counting Book - 24 - 2001.
# Prayers for Children (Little Golden Book) - 24 - 1999.
# Cooking With the Cat (The Cat in the Hat: Step Into Reading, Step 1) - 32 - 2003.
# Be My Baby - 384 - 2012.
# Handmade Cards (Step-by-Step Children's Crafts) - 32 - 2002.
# When Jesus Was Young (The Lion Story Bible, No. 33) - 22 - 1986.
# Quick as a Cricket - 32 - 1982.
# Puzzle Island (Child's Play Library) - 24 - 1990.
# Town Mouse, Country Mouse - 32 - 1994.
# Treasure of the Sun - 448 - 2010.
# Nina, Nina Star Ballerina (Penguin Young Readers, Level 2) - 32 - 1997.
# Fifty States Quarters (coin Collecting Kit) - 32 - 2000.
# Winnie the Pooh and Tigger Too (Disney's Wonderful World of Reading) - 42 - 1976.
# Richard Scarry's Best Friend Ever (Look-Look) - 24 - 1989.
# Awareness Through Movement: Easy-to-Do Health Exercises to Improve Your Posture, Vision, Imagination, and Personal Awareness - 192 - 2009.
# Find Your Courage: 12 Acts for Becoming Fearless at Work and in Life - 320 - 2009.
# Honor Among Thieves : Captain Kidd, Henry Every, and the Pirate Democracy in the Indian Ocean - 2 - 2000.
# Denali Journal - 2 - 1992.
# The Joke Book (Pictureback(R)) - 32 - 1979.
# Jacob Have I Loved - 256 - 2020.
# Walk Two Moons - 288 - 2019.
# Boys Will Be Boys: Breaking the Link Between Masculinity and Violence - 386 - 2019.
# The Moon Seems to Change (Let's-Read-and-Find-Out Science 2) - 32 - 1987.
# Get Up and Go! (MathStart 2) - 40 - 1996.
# Geometric Allover Patterns (Dover Pictorial Archive) - 48 - 1985.
# Dino-birds: From Dinosaurs to Birds - 64 - 2022.
# Stacey's Lie (Baby-Sitters Club, 76) - 10 - 1994.
# The Snowy Day Board Book - 16 - 1996.
# The Gnome From Nome (Serendipity) - 32 - 1978.
# C D B! - 48 - 1987.
# Toasting Marshmallows: Camping Poems - 48 - 2001.
# A to Z - 14 - 1984.
# Color Dance - 40 - 1989.
# Spiders Eyes On Nature - 29 - 1996.
# If You Were an Astronaut (Look-Look) - 24 - 1985.
# HERstory:: Lisa Marie's Wedding Diary - 1 - 1996.
# Sweet Clara and the Freedom Quilt (A Borzoi Book) - 40 - 2018.
# Many Lives of Benjamin Franklin, The - 32 - 1988.
# Trick or Treat, Smell My Feet (Gilbert the Opossum) - 32 - 1998.
# King of the Dinosaurs: Tyrannosaurus Rex (A Golden Little Look-Look Book) - 24 - 1989.
# Creole (A Serendipity Book) - 32 - 1978.
# The Highwayman - 32 - 1999.
# Little Pig's Tale - 26 - 1990.
# A Kwanzaa Celebration Pop-Up Book : CELEBRATING THE HOLIDAY WITH NEW TRADITIONS AND FEASTS - 14 - 1995.
# A Bug's Life (Disney Pixar) - 24 - 1998.
# The Dark Room - 48 - 1997.
# Uncle Pete the Pirate (Usborne Young Puzzle Adventures) - 32 - 1994.
# Nate the great and the stolen base - 47 - 1992.
# Oswald Makes Music (Nick Jr. Book Club) - 36 - 2002.
# The Radish Day Jubilee (A Fraggle Rock Book Starring Jim Henson's Muppets) - 44 - 1983.
# More Bunny Trouble (rev) - 32 - 2001.
# Chugga Chugga Choo Choo - 32 - 1999.
# Meet Me for Coffee - 47 - 1998.
# Lucy's Child: The Discovery of a Human Ancestor - 16 - 1990.
# Hattie and the Wild Waves: A Story From Brooklyn (Picture Puffins) - 48 - 1993.
# Green Wilma (Puffin Pied Piper) - 32 - 1998.
# Max's Chocolate Chicken (Max and Ruby) - 32 - 2000.
# Clifford The Big Red Dog - 32 - 2002.
# Miss Fannie's Hat - 32 - 2001.
# The Coiled Viper (The Secrets of Droon #19) - 131 - 2015.
# Barbie.com: Ballet Buddies (Step-Into-Reading, Step 3) - 48 - 2000.
# The Turning of the Year - 28 - 1998.
# The Water Hole - 32 - 2004.
# All Hat - None - 2022.
# The Dragon and the Unicorn - 36 - 1998.
# Big Frank's Fire Truck (Pictureback(R)) - 32 - 1996.
# Sisters - 32 - 2003.
# Tales, Trails and Tommyknockers: Stories from Colorado's Past - 144 - 2012.
# Extra Innings: Baseball Poems - 48 - 1993.
# The Napping House - 32 - 2009.
# Pets in Trumpets: And Other Word-Play Riddles - 32 - 1991.
# Postcards from Pluto: A Tour of the Solar System - 32 - 1995.
# The Berenstain Bears and Too Much Teasing - 32 - 1995.
# Creatures of the Desert World - 16 - 1991.
# Little Prayer Series: Bedtime Prayers - 12 - 1995.
# The Path: the Inner Life of Jesus Christ - 262 - 2015.
# Clifford's Word Book - 28 - 1990.
# Mine Eyes Have Seen - 1 - 2002.
# Let's Talk About Feeling Sad - 32 - 1996.
# Germs! Germs! Germs! (Hello Reader! Level 3 Science) - 38 - 1996.
# Harry and the Terrible Whatzit - 40 - 1984.
# Cyndy Szekeres' I Love My Busy Book: About the Alphabets, Counting, Colors, Opposites, Shapes and Much, Much More! - 46 - 1997.
# Favourite Farmhouse Recipes - 48 - 1993.
# The Day the Dog Said, Cock-A-Doodle-Doo - 32 - 1997.
# Goodnight Moon - 37 - 2016.
# Christmas Day in the Morning - 40 - 2002.
# Huggly and the Books (SeeSaw Book Club) - 8 - 2001.
# Urban Voodoo: A Beginners Guide to Afro-Caribbean Magic - 192 - 2011.
# The Lost Ones (Star Wars: Young Jedi Knights, Book 3) - 1 - 1997.
# Good Night Baby (Soft-to-Touch Books) - 20 - 1995.
# Pierre: A Cautionary Tale in Five Chapters and a Prologue - 48 - 1991.
# The ABC Mystery - 32 - 1993.
# Leo the Late Bloomer - 32 - 1999.
# Forest (An I Can Read Book) - 48 - 1998.
# Piecing - 162 - 2010.
# De oca a oca (Colección Ancora y delfín) (Spanish Edition) - 273 - 2021.
# Skywalking: The Life And Films Of George Lucas, Updated Edition - 368 - 2009.
# PMS Attacks and Other Inconveniences of Life: The Saga Continues - 1 - 1990.
# Dinosaurs! Strange and Wonderful (Picture Puffins) - 32 - 1996.
# The Big Green Bean (A Magic Circle Book) - 24 - 1974.
# The Perfect Puppy for Me - 32 - 2003.
# Asterix and the Actress - 48 - 2002.
# Asterix and the Secret Weapon: Album #29 (Asterix Adventure) - 48 - 2002.
# California Gold Rush: A guide to California in the 1850s (Sightseers) - 31 - 1999.
# Three Cheers for Tacky (Tacky the Penguin) - 32 - 1996.
# December - 48 - 1996.
# Disney's Beauty and the Beast - 24 - 1991.
# Elves And Shoemaker (A Pudgy Pal Board Book) - 1 - 1993.
# Marsha Makes Me Sick (Step-Into-Reading, Step 3) - 48 - 1998.
# Escape from Five Shadows - 288 - 2019.
# Love You Forever - 32 - 1995.
# Chicken Soup with Rice: A Book of Months - 32 - 1991.
# Yoss - 298 - 2021.
# Sweet Thing (Cheek) - 256 - 2010.
# The Magic School Bus Meets The Rot Squad: A Book About Decomposition - 32 - 1995.
# The Magic School Bus Inside the Human Body - 40 - 1990.
# Strangers' Bread - 30 - 1977.
# Millicent and the Wind (Annikin) - 32 - 1988.
# Carl's Christmas - 32 - 1990.
# Phoenix - 10 - 1990.
# Elmo's World: Puppies! (Sesame Street) (Sesame Street(R) Elmos World(TM)) - 12 - 2012.
# Nightprowlers (A Gulliver Green Book) - 48 - 1994.
# Here's to You, America! (Peanuts) - 32 - 2002.
# The gull that lost the sea (A Little golden book) - 24 - 1984.
# Here Comes the Recycling Truck! - 32 - 1992.
# Star of Fear, Star of Hope - 32 - 1996.
# Arthur's Halloween: An Arthur Adventure (Arthur Adventures) - 32 - 1982.
# Redemption Ark (Gollancz) - 576 - 2022.
# Irene Jennie and the Christmas Masquerade: The Johnkankus - 32 - 1996.
# Bones: Our Skeletal System - 32 - 2000.
# The Mitten - 40 - 1989.
# Building a House (Mulberry Books) - 32 - 1990.
# Hug - 32 - 2001.
# Animal quiz book (Little Golden Books) - 24 - 1983.
# Tacky the Penguin - 32 - 1990.
# Cowardly Clyde - 48 - 1984.
# COMPLETE SLAVE - 100 - 2015.
# I Can Dress Myself (Little Golden Book) - 24 - 1994.
# I Promise - 368 - 2013.
# Open Season (A Joe Pickett Mystery) - 296 - 2022.
# Thomas' Snowsuit (Munsch for Kids) - 24 - 1985.
# The Planet Eater (space Hawks, Book 6) - 10 - 1992.
# Barney Goes To The Dentist - 24 - 1997.
# JEALOUS LIES (Sweet Valley High) - 10 - 1986.
# Dogs (A New True Book) - 45 - 1981.
# A Visit to the Big House - 46 - 1993.
# Bingo! (Bunny Reads Back) - 18 - 1999.
# Clifford Takes A Trip - 32 - 1992.
# Easy Science Experiments - 48 - 1993.
# I Spy Fun House: A Book of Picture Riddles - 40 - 1993.
# Platoon Leader - 10 - 1986.
# The cookie house (A Follett just beginning-to-read book) - 28 - 1978.
# Gossie and Gertie (Gossie & Friends) - 32 - 2002.
# Just Grandma and Me (Little Critter) (Pictureback(R)) - 24 - 2001.
# There Was an Old Lady Who Swallowed a Fly - 36 - 1997.
# Imagist Poetry: An Anthology (Dover Thrift Editions) - 176 - 2011.
# Plants We Know (New True Books) - 45 - 1981.
# Three Greek Romances - None - 2022.
# The Christmas Witch (Bank Street Level 3*) - 48 - 1993.
# I Just Forgot (A Little Critter Book) - 24 - 1999.
# Tony Robins 2 Books Collection Set (Awaken The Giant Within How to Take Immediate Control of Your Mental,Emotional,Physical & Unlimited Power The New Science of Personal Achievement) - 448 - 2019.
# Black on White - 12 - 1993.
# The Stubborn Pumpkin (Hello Reader, Level 3) - 32 - 1999.
# The Magic School Bus on the Ocean Floor - 48 - 1992.
# Michigan (America) - 96 - 2010.
# Why Do We Say? The Stories Behind the Words, Expressions and Cliches We Use - 286 - 2009.
# The Life of Saint Nicholas - 1 - 1996.
# Jamie O'Rourke and the Pooka - 32 - 2002.
# The Tigger Movie (A golden storybook) - 24 - 2000.
# Xavier's Fantastic Discovery (Cabbage Patch Kids) - 42 - 1984.
# Dream Wolf (Aladdin Picture Books) - 32 - 1997.
# American Beauty Sight and Sound Edition - 192 - 2021.
# One, Two, Three! (Boynton on Board) - 24 - 1993.
# Bill Nye the Science Guy's Big Blue Ocean - 48 - 2003.
# Fingerprints Of The Gods & Magicians of the Gods By Graham Hancock 2 Books Collection Set - 592 - 2020.
# Among Sisters: Short Stories by Women Writers - 1 - 1989.
# I Never Said I Wasn't Difficult - 48 - 1997.
# No, David! - 32 - 1998.
# The Reason for a Flower: A Book About Flowers, Pollen, and Seeds (Explore!) - 48 - 1999.
# Ready, Set, Go!: Board book - 11 - 2000.
# Five Little Monkeys Sitting in a Tree (A Five Little Monkeys Story) - 32 - 1993.
# Three Cheers for Tacky (Tacky the Penguin) - 32 - 1994.
# The Solar Home (How-To Guides) - 2 - 1994.
# If You Are a Hunter of Fossils (Reading Rainbow Book) - 32 - 1984.
# Cool Chameleons (camaleones) Level 2 (Hola, Lector!, Ciencias. Nivel 2.) - 32 - 2002.
# Don't Laugh, Joe! - 32 - 1997.
# Gingerbread Baby - 32 - 1999.
# Joseph Man of Dreams/24-03932 (Now You Can Read) - 23 - 1990.
# Dragonlance Legends (Dragonlance Legends Paperback) - 3 - 1988.
# Black Sky River - 1 - 1996.
# Lessons on Assurance: Five Life-Changing Bible Studies and Memory Verses for New Christians (Growing in Christ) - 32 - 1980.
# The Unicorn and the Lake - 32 - 1982.
# Handy-Dandy Helpful Hal: A Book About Helpfulness (Building Christian Character) - 31 - 1987.
# Socks for Supper - 32 - 1978.
# DORI STORIES - 100 - 2015.
# Peter Cottontail's surprise - 44 - 1985.
# The Greeks (Crafts from the Past) - 32 - 1998.
# I Already Know I Love You - 40 - 2004.
# The Drag Queen of Elfland and Other Stories - 100 - 2015.
# Drowning Man - 256 - 2022.
# The Other End of the Leash: Why We Do What We Do Around Dogs - 272 - 2022.
# Before the Flood - 1 - 2003.
# Fortune-Telling by Tarot Cards - 224 - 2009.
# Cowboys (All Aboard Books (Paperback)) - 32 - 1996.
# North Dallas after Forty - 1 - 1990.
# I Know an Old Lady Who Swallowed a Fly - 32 - 1980.
# Soul Solution - 198 - 2021.
# Walt Disney's Cinderella (Golden Books) - 24 - 1993.
# Michelin Spain Northern Map No. 442 (Michelin Maps & Atlases) - 17 - 2000.
# Le Chat du Rabbin - La Bar-Mitsva (POISSON PILOTE) (French Edition) - 48 - 2002.
# Alphabeasts - 32 - 2002.
# Das Monokel: Roman (DTV Premium) (German Edition) - 375 - 2022.
# Baby and Friends (Soft-to-Touch Books) - 20 - 1995.
# Stücke I. (German Edition) - None - 2021.
# The Runaway Bunny - 48 - 2017.
# NYMPH - 100 - 2015.
# Farewells to Plasma (Short Stories) - 100 - 2015.
# Ramito de hierbabuena (Spanish Edition) - 316 - 2022.
# Ciudad rayada (Spanish Edition) - 223 - 2022.
# George Washington Carver (On My Own Biography) - 48 - 2000.
# Garzanti - Gli Elefanti: Monte Cinque - 241 - 2021.
# Dear Mrs. LaRue: Letters from Obedience School (LaRue Books) - 32 - 2003.
# Once a Mouse... - 32 - 1972.
# Okomi the New Baby (Okomi Series) - 24 - 2001.
# They Called Her Styrene, Etc. - 1 - 2000.
# The Three Bears - 24 - 2012.
# Little House on the Prairie Series 7 Books Collection by Laura Ingalls Wilder - 352 - 2020.
# The Grouchy Ladybug - 48 - 1996.
# Slow Hand: Women Writing Erotica - 256 - 2012.
# Married to the Viscount (Swanlea Spinsters, Book 5) - 384 - 2014.
# Caste as woman - 240 - 2022.
# Scooby-Doo and the Ghastly Giant (Scooby-doo 8x8) - 32 - 2003.
# Deep in the Forest (Picture Puffins) - 32 - 1992.
# The Funny Little Woman (Puffin Unicorn) - 40 - 1993.
# Simple Signs (Picture Puffins) - 32 - 1997.
# Fish Eyes: A Book You Can Count On - 40 - 2001.
# There was an Old Lady Who Swallowed a Bat! - 32 - 2002.
# 1984 (Folio) (French Edition) - 407 - 2017.
# No Need for Monty - 32 - 1987.
# Ride the River: The Sacketts: A Novel - 186 - 2010.
# Arthur's First Sleepover: An Arthur Adventure (Arthur Adventures) - 30 - 1999.
# Arthur's Teacher Trouble (Arthur Adventures (Paperback)) - 30 - 1989.
# Crazy Sexy Cool - 1 - 1996.
# Zom-B and Cirque du Freak Series 24 Books Collection Set by Darren Shan - 240 - 2019.
# War and Peace (Life Skills & Responsibility) - 32 - 1991.
# The Night Before Christmas - 32 - 1995.
# Baby Earth - 1 - 1996.
# The Berenstain Bears and the Papa's Day Surprise - 32 - 2003.
# Mouse's Hide-and-Seek Words (Step into Reading) - 32 - 2003.
# Animal Sense - 48 - 2003.
# Philip Pullman His Dark Materials & The Book of Dust Vol 1 & 2 Collection 4 Books Set (Lyra's Oxford, Once Upon a Time in the North, La Belle Sauvage, The Secret Commonwealth) - 64 - 2020.
# The Mouse and the Motorcycle - 176 - 2016.
# Ramona the Pest - 240 - 2020.
# Shadow of a Dark Queen (The Serpentwar Saga, Book 1) - 497 - 2010.
# Morning Song - 400 - 2011.
# The Tea Planter's Bride - 416 - 2012.
# Suddenly You - 384 - 2020.
# The Runaway Princess: Princesses, Book 1 (The Princess Series) - 384 - 2018.
# The West End Horror: A Posthumous Memoir of John H. Watson, M.D. (The Journals of John H. Watson, M.D.) - 198 - 2013.
# I Shall Not Be Moved - 48 - 1990.
# Work Is Hell - 48 - 1986.
# The Berenstain Bears Get the Gimmies - 32 - 1988.
# The Berenstain Bears and the Missing Dinosaur Bone - 40 - 1980.
# And to Think That I Saw It on Mulberry Street - 40 - 1989.
# The Berenstain Bears Visit the Dentist - 32 - 1981.
# Wake Up, Sun! (Step-Into-Reading, Step 2) - 32 - 1986.
# Richard Scarry's Bedtime Stories (Pictureback(R)) - 32 - 1986.
# Sir Small and the Dragonfly (Step into Reading) - 32 - 1988.
# Miss Nelson Is Missing! (Read Along Book) - 32 - 1985.
# Sheep in a Jeep - 32 - 1986.
# Annie and the Wild Animals (Send a Story) - 32 - 1989.
# Nannabah's Friend - 6 - 1989.
# Five Little Monkeys Jumping on the Bed - 14 - 1998.
# Seal Team Seven - 1 - 1994.
# Open Weave - 1 - 1997.
# The Story of the Cherokee People - 48 - 1961.
# The Protocol - 1 - 2000.
# The Hallo-Wiener - 32 - 1999.
# Pee Wee Scouts: Piles of Pets (A Stepping Stone Book(TM)) - 112 - 2009.
# Where the Red Fern Grows - 304 - 2016.
# Moon And The Thorn - 1 - 1995.
# Toy Story: A Toy's Guide to Life - 1 - 1995.
# Seven Clans of the Cherokee Society - 32 - 1993.
# How Tough Was a Tyrannosaurus? (Reading Railroad) - 32 - 1989.
# Max and Ruby's Busy Week - 32 - 2002.
# Kate Skates (Penguin Young Readers, Level 2) - 32 - 1995.
# All About Cats and Kittens (Reading Railroad) - 32 - 1999.
# Night-Night, Baby: A Touch-and-Feel Book - 12 - 2000.
# The Road to Avalon - 1 - 1989.
# Common Sense - 82 - 2014.
# Medieval Designs Iron-on Transfer Patterns - 48 - 1997.
# Sleeping Beauty: Full-Color Sturdy Book (Dover Little Activity Books) - 12 - 1997.
# Antony and Cleopatra (Dover Thrift Editions) - 128 - 2014.
# Tar Beach - 32 - 1996.
# My Little Sister Ate One Hare (Dragonfly Books) - 32 - 1998.
# The Independence of Spanish America (Cambridge Latin American Studies) - 296 - 2009.
# George Told Kate - 32 - 1987.
# Sam's Sandwich - 24 - 1991.
# Baby Jesus (My First Bible Board Book) - 3 - 1984.
# Joshua's Night Whispers - 1 - 1994.
# Man Of The Shadows (Spanish Bit #5) - 10 - 1988.
# The Unicorns at War (Unicorn Club) - 10 - 1995.
# Stone Soup - 32 - 1986.
# The Bremen-town Musicians (Easy-To-Read Folktales) - 32 - 1992.
# Mein Erstes T-Shirt - None - 2022.
# Popcorn (Acting Edition) - 66 - 2011.
# Don't Drink the Water - 88 - 2010.
# Second-Grade Ape (Hello Reader) - 48 - 1998.
# Up Day, Down Day - 32 - 1978.
# A Bad, Bad Day (My First Hello Reader) - 32 - 1996.
# The Baby-Sitters Club Super Special #10: Sea City, Here We Come - 227 - 2013.
# O Jerusalem - 32 - 2001.
# Enoch, the emu - 32 - 1986.
# Dinosaurs The Fastest, The Fiercest, The Most Amazing - 32 - 1995.
# Festival of Lights: The Story of Hanukkah - 23 - 1987.
# Opposites - 16 - 1982.
# The Pumpkinville Mystery - 32 - 1991.
# One To Ten Pop-Up Surprises! - 10 - 1995.
# Baseball Ballerina (Step into Reading, Step 3) - 48 - 1992.
# The Berenstain Bears and the Prize Pumpkin - 32 - 1990.
# Mary (Vintage International) - 142 - 2011.
# Wild, Wild Wolves (Step into Reading) - 48 - 1992.
# The Story of Hanukkah (Pictureback(R)) - 24 - 1995.
# It's Your Bed, Fred! (Jellybean Books) (Muppets) - 24 - 1999.
# Monster Munchies (Beginner Books) - 48 - 1998.
# Ramona Quimby, Age 8 - 190 - 2020.
# Badger's Parting Gifts - 32 - 1992.
# Wemberly Worried - 32 - 2000.
# There's a Monster Under My Bed - 32 - 1990.
# The Good-bye Book - 32 - 1992.
# Big Pumpkin - 32 - 1995.
# Pigs Go to Market: Halloween Fun with Math and Shopping (Pigs Will Be Pigs) - 40 - 1997.
# The Faithful Friend - 40 - 1999.
# Dear Fairies - 18 - 1999.
# Bear Snores On - 1 - 2002.
# Rocket Power Joke Book - 48 - 2001.
# Can't You Make Them Behave, King George? - 48 - 1996.
# Chicken Sunday - 32 - 1998.
# My Beautiful Broken Shell: Words of Hope to Refresh the Soul - 48 - 2002.
# Doctor Maisy - 24 - 2001.
# 54 3-D Scroll Saw Patterns (Schiffer Book for Woodturners) - 48 - 1996.
# The New York Knicks Basketball Team (Great Sports Teams) - 48 - 2000.
# P.B. Bear Board Book: Words - 14 - 2001.
# DK Readers: Volcanoes and Other Natural Disasters (Level 4: Proficient Readers) (DK Readers Level 4) - 48 - 1998.
# Baby Faces - 16 - 1998.
# DK Readers: Big Machines (Level 1: Beginning to Read) (DK Readers Level 1) - 32 - 2000.
# DK Readers: Twisters! (Level 2: Beginning to Read Alone) - 32 - 2000.
# DK Readers: A Day in a Life of a Builder (Level 1: Beginning to Read) (Jobs People Do series) - 32 - 2001.
# Fuzzy Yellow Ducklings - 32 - 1995.
# The Grand Inquisitor (Milestones of Thought) - 40 - 1981.
# A Reading Course in Homeric Greek: Book 1 (English and Ancient Greek Edition) - 2 - 1985.
# Snow Ponies - 32 - 2001.
# They Saw the Elephant: Women in the California Gold Rush - 290 - 2013.
# Plant-and-Grow Project Bk - 48 - 1993.
# Bizarre Beasts: And Other Oddities of Nature - 29 - 1996.
# Ten Little Rabbits - 32 - 1995.
# My Friends - 40 - 1995.
# Getting to Know France and French (Getting to Know Series) - 32 - 1993.
# Salome' - 102 - 2013.
# The Monster Under My Bed (A Giant First-Start Reader) - 28 - 1985.
# Rabbit's New Rug - 40 - 1980.
# Masque of Sapphire - 1 - 1990.
# A Picture Book of Anne Frank (Picture Book Biography) - 32 - 1993.
# My Own Worst Enemy - 32 - 1999.
# Mel Bay You Can Teach Yourself Guitar (You Can Teach Yourself) (You Can Teach Yourself) - 112 - 2015.
# Students Guide to Liberal Learning: Liberal Learning Guide (Guides to Major Disciplines) - 60 - 2019.
# You Are Special (Volume 1) (Max Lucado's Wemmicks, Volume 1) - 32 - 1997.
# Little Puppy Saves the Day (Little Animal Adventures) - 1 - 1993.
# Youth Ministry in Small Churches - 168 - 2009.
# My First Sewing Book: Hand Sewing - 40 - 1995.
# I Died Laughing: Funeral Education with a Light Touch - 96 - 2010.
# Squee - 144 - 2019.
# Pope Fiction: Answers to 30 Myths & Misconceptions About the Papacy - 338 - 2016.
# Skymates: Love, Sex and Evolutionary Astrology (Volume 1) - 342 - 2016.
# Sixty Million Frenchmen Can’t Be Wrong: Why We Love France but Not the French - 351 - 2020.
# The Jade Peony - 240 - 2011.
# New Mexico (America) - 96 - 2010.
# A grammar of endings - 151 - 2022.
# The Classic Tale Of Ginger and Pickles - 24 - 1992.
# Trick Is to Keep Breathing (Scottish Literature) - 240 - 2015.
# The Perl CD Bookshelf: Perl in a Nutshell/Programming Perl, 2nd Edition/Perl Cookbook/Advanced Perl Programming/Learning Perl, 2nd Edition/Learning Perl on WIN32 Systems - 1 - 1999.
# A Man, a Can, a Plan : 50 Great Guy Meals Even You Can Make - 43 - 2002.
# Everyone is Special (Lessons From the Hundred Acre Wood, No. 2 / Disney's Winnie The Pooh) - 28 - 2000.
# Battlefield Earth: Science Fiction New York Times Best Seller - 1008 - 2011.
# Pepperidge Farm Goldfish Counting Board - 12 - 1998.
# Memory Makers Photo Kaleidoscopes: Creating Dramatic Photo Art on Your Scrapbook Pages - 34 - 1999.
# Michael Swanwick's Field Guide to Mesozoic Megafauna - 34 - 2004.
# FILOSOFIA DE LAS CIENCIAS HUMANAS Y SOCIALES (Autores, Textos y Temas) (Spanish Edition) - 416 - 2012.
# Moo, Baa, La La La! - 16 - 1982.

# %% [markdown]
# ## Projections

# %%
filter = { 
    "$and": [
        { "pages": { "$lt": 50 }},
        { "year": { "$gt" : 2008 }}
    ]
}

projection = {
    "title": 1,
    "pages": 1,
    "year": 1,
}

results = books.find(filter, projection)

for f in results:
    print(f)
# Out:
# {'_id': '684190702', 'title': 'Sweet Clara and the Freedom Quilt (A Borzoi Book)', 'pages': 40, 'year': 2018}
# {'_id': '156007096', 'title': 'The Napping House', 'pages': 32, 'year': 2009}
# {'_id': '006446704X', 'title': 'Goodnight Moon', 'pages': 37, 'year': 2016}
# {'_id': '380755343', 'title': "Elmo's World: Puppies! (Sesame Street) (Sesame Street(R) Elmos World(TM))", 'pages': 12, 'year': 2012}
# {'_id': '64470067', 'title': 'The Runaway Bunny', 'pages': 48, 'year': 2017}
# {'_id': '310238463', 'title': 'The Three Bears', 'pages': 24, 'year': 2012}

# %% [markdown]
# Exclude `_id` field

# %%
filter = { 
    "$and": [
        { "pages": { "$lt": 50 }},
        { "year": { "$gt" : 2008 }}
    ]
}

projection = {
    "_id": 0,
    "title": 1,
    "pages": 1,
    "year": 1,
}

results = books.find(filter, projection)

for f in results:
    print(f)
# Out:
# {'title': 'Sweet Clara and the Freedom Quilt (A Borzoi Book)', 'pages': 40, 'year': 2018}
# {'title': 'The Napping House', 'pages': 32, 'year': 2009}
# {'title': 'Goodnight Moon', 'pages': 37, 'year': 2016}
# {'title': "Elmo's World: Puppies! (Sesame Street) (Sesame Street(R) Elmos World(TM))", 'pages': 12, 'year': 2012}
# {'title': 'The Runaway Bunny', 'pages': 48, 'year': 2017}
# {'title': 'The Three Bears', 'pages': 24, 'year': 2012}
