# %% [markdown]
# # $unwind

# %%
from pymongo import MongoClient

uri = "mongodb://admin:mongodb@localhost:27017/"
client = MongoClient(uri)
library_database = client["library"]

books = library_database["books"]

# %%
pipeline = [
  { "$unwind" : "$attributes" },
  { "$match": {"attributes.key": "msrp", "attributes.value": 9.99} },
  { "$project": {"title": 1, "attributes": 1} },
  {"$limit": 10}
]

cursor = books.aggregate(pipeline)

for f in cursor:
    print(f"{f}.")
# Out:
# {'_id': '0060509295', 'title': 'A Few Short Notes on Tropical Butterflies: Stories', 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0060528125', 'title': "Mary-Kate & Ashley Sweet 16 #6: My Best Friend's Boyfriend: (My Best Friend's Boyfriend) (MARY-KATE AND ASHLEY SWEET 16)", 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0060913401', 'title': "Why Johnny Can't Read: And What You Can Do about It", 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0060922362', 'title': 'Slow Hand: Women Writing Erotica', 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0060930284', 'title': 'Loving Chloe: A Novel', 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0064409449', 'title': "Prince Caspian: The Return to Narnia (The Chronicles of Narnia - Full-Color Collector's Edition)", 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0310234840', 'title': "The Case for Christ: A Journalist's Personal Investigation of the Evidence for Jesus (Student Edition)", 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0310271711', 'title': 'Finding the Will of God in a Crazy, Mixed-Up World', 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0312247052', 'title': 'All About the Dixie Chicks', 'attributes': {'key': 'msrp', 'value': 9.99}}.
# {'_id': '0312422571', 'title': 'Writing Home', 'attributes': {'key': 'msrp', 'value': 9.99}}.
