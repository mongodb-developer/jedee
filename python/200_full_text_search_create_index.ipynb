# %% [markdown]
# Aggregation Pipeline Lab

# %% [markdown]
# # Full Text Search - Create FTS Index

# %% [markdown]
# ## Startup code

# %%
# Import the MongoDB Driver
from pymongo import MongoClient
from pymongo.operations import SearchIndexModel

# Connect to the MongoDB Server
client = MongoClient("mongodb://admin:mongodb@localhost:27017/?directConnection=true")

# Access a Database
db_name = "library"
db = client[db_name]

# Access a Collection
books = db['books']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [47], line 3
#       1 # Import the MongoDB Driver
#       2 from pymongo import MongoClient
# ----> 3 from pymongo.operations import SearchIndexModel
#       5 # Connect to the MongoDB Server
#       6 client = MongoClient("mongodb://admin:mongodb@localhost:27017/?directConnection=true")
#
# ImportError: cannot import name 'SearchIndexModel' from 'pymongo.operations' (/usr/lib/python3/dist-packages/pymongo/operations.py)

# %% [markdown]
# ## create_search_index()
#
# https://www.mongodb.com/docs/languages/python/pymongo-driver/current/indexes/#create-a-search-index

# %%
books.create_search_index = {
    "name": "default",
    "definition": {
        "mappings": {
            "dynamic": True
        }
    }
}

# %% [markdown]
# ## Check that the index has been created

# %%
# List Existing Search Indexes
# indexes = books.list_search_indexes()
for index in indexes:
    print(f"Indexes: {index['name']}")
